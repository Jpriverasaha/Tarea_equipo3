# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:**Juan Pablo Rivera
#
# **Fecha:** 31 de octubre del 2020.
#
# **Expediente** : If714314
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# # Tarea 8:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st     
import pandas as pd

# %%
## a)
fx = lambda x:(3/2)*(x ** 2) if -1 <= x <= 1 else 0
Fx = lambda x: x**(1/3) if x >= 0 else -(-x)**(1/3)
f_inv = lambda u : Fx((2*u)-1)
N = 1000
u1 = np.random.uniform(0,1,N)
muestras = list(map(lambda x : f_inv(x),u1))

y,x,p = plt.hist(muestras, bins=20, density=True)
y2 = list(map(lambda x: fx(x),x))
plt.plot(x,y2,'r')
plt.show()

# %%
m1 = list(map(lambda x: f_inv(x), u1))
np.mean(m1)
# Out:
# -0.03245580226500944

# %%
## b)

r1 = np.random.uniform(0,0.6,3)
r2 = np.random.uniform(0.6,0.9,3)
r3 = np.random.uniform(0.9,1,4)
y = [1/2,1,4]
r = [r1,r2,r3]

muestras = [list(map(lambda x: f_inv(x), i)) for i in r]
estrato = [list(map(lambda i, y: i/y, i,y))for i in muestras]
np.concatenate(estrato).mean()
# Out:
# 0.4193123451648695

# %%
## c)

def estratos(x):
    U2 =np.random.rand(x)
    i =np.arange(0,x)
    estratos = (U2+i)/x
    return estratos
random = estratos(10)
muestras2 = list(map(lambda x: f_inv(x), random))
np.mean(muestras2)
# Out:
# 0.02797778579222674

# %%
u1 = np.random.rand(10)
U2 = 1-u1
U =[u1,U2]
muestras3 =[list(map(lambda x: f_inv(x), i)) for i in U] 
np.concatenate(muestras3).mean()
# Out:
# -1.6653345369377347e-17
